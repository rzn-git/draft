# %%
import pandas as pd
import os

# Get the path to the folder containing the CSV file
folder_path = "C:\\Users\\rzn\\Desktop\\NYC Vehicle Collision Analytics"

# Get the path to the CSV file
csv_file_path = os.path.join(folder_path, "NYC_Vehicle_Collision.csv")

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)

# View the head of the DataFrame
df.head()
# Out:
# C:\Users\rzn\AppData\Local\Temp\ipykernel_15040\1393810302.py:11: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#    CRASH_DATE CRASH_TIME BOROUGH ZIP_CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  04/14/2020      11:00     NaN      NaN       NaN        NaN      NaN
# 1  06/13/2016      17:10     NaN      NaN       NaN        NaN      NaN
# 2  06/13/2016      17:30     NaN      NaN       NaN        NaN      NaN
# 3  08/02/2018       9:30     NaN      NaN       NaN        NaN      NaN
# 4  06/13/2016      18:00     NaN      NaN       NaN        NaN      NaN
#
#                      ON_STREET_NAME CROSS_STREET_NAME  \
# 0  VERRAZANO BRIDGE UPPER                         NaN
# 1  STATEN ISLAND EXPY                             NaN
# 2  MAJOR DEEGAN EXPRESSWAY                        NaN
# 3                               NaN               NaN
# 4  WEST SHORE EXPRESSWAY                          NaN
#
# ...

# %%
# Keep the first 120000 rows
df = df[:100000]

# Delete the rest of the rows
#df = df.dropna()

# Get the path to the desktop
desktop_path = os.path.expanduser("~/Desktop")

# Write the updated DataFrame to a new CSV file on the desktop
df.to_csv(os.path.join(desktop_path, "small_csv_file.csv"), index=False)
